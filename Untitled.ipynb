# %%
import pandas
import requests
import io

# %%
base_url = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/'
conf_file = 'time_series_19-covid-Confirmed.csv'
deaths_file = 'time_series_19-covid-Deaths.csv'
recov_file = 'time_series_19-covid-Recovered.csv'

# %%
def get_table_from_url(url):
    csv_raw_text = requests.get(url).text
    csv_buffer = io.StringIO(csv_raw_text)
    
    return pandas.read_csv(csv_buffer)

# %%
conf = get_table_from_url(base_url + conf_file)
conf.tail()
# Out:
#     Province/State         Country/Region      Lat    Long  1/22/20  1/23/20  \
# 496            NaN                 Jersey  49.1900  -2.110        0        0
# 497            NaN            Puerto Rico  18.2000 -66.500        0        0
# 498            NaN  Republic of the Congo  -1.4400  15.556        0        0
# 499            NaN            The Bahamas  24.2500 -76.000        0        0
# 500            NaN             The Gambia  13.4667 -16.600        0        0
#
#      1/24/20  1/25/20  1/26/20  1/27/20  ...  3/14/20  3/15/20  3/16/20  \
# 496        0        0        0        0  ...        0        0        0
# 497        0        0        0        0  ...        0        0        0
# 498        0        0        0        0  ...        0        0        0
# 499        0        0        0        0  ...        0        0        0
# 500        0        0        0        0  ...        0        0        0
#
#      3/17/20  3/18/20  3/19/20  3/20/20  3/21/20  3/22/20  3/23/20
# ...

# %%
deaths = get_table_from_url(base_url + deaths_file)
deaths.tail()
# Out:
#     Province/State         Country/Region      Lat    Long  1/22/20  1/23/20  \
# 496            NaN                 Jersey  49.1900  -2.110        0        0
# 497            NaN            Puerto Rico  18.2000 -66.500        0        0
# 498            NaN  Republic of the Congo  -1.4400  15.556        0        0
# 499            NaN            The Bahamas  24.2500 -76.000        0        0
# 500            NaN             The Gambia  13.4667 -16.600        0        0
#
#      1/24/20  1/25/20  1/26/20  1/27/20  ...  3/14/20  3/15/20  3/16/20  \
# 496        0        0        0        0  ...        0        0        0
# 497        0        0        0        0  ...        0        0        0
# 498        0        0        0        0  ...        0        0        0
# 499        0        0        0        0  ...        0        0        0
# 500        0        0        0        0  ...        0        0        0
#
#      3/17/20  3/18/20  3/19/20  3/20/20  3/21/20  3/22/20  3/23/20
# ...

# %%
recov = get_table_from_url(base_url + recov_file)
recov.tail()
# Out:
#     Province/State         Country/Region      Lat    Long  1/22/20  1/23/20  \
# 496            NaN                 Jersey  49.1900  -2.110        0        0
# 497            NaN            Puerto Rico  18.2000 -66.500        0        0
# 498            NaN  Republic of the Congo  -1.4400  15.556        0        0
# 499            NaN            The Bahamas  24.2500 -76.000        0        0
# 500            NaN             The Gambia  13.4667 -16.600        0        0
#
#      1/24/20  1/25/20  1/26/20  1/27/20  ...  3/14/20  3/15/20  3/16/20  \
# 496        0        0        0        0  ...        0        0        0
# 497        0        0        0        0  ...        0        0        0
# 498        0        0        0        0  ...        0        0        0
# 499        0        0        0        0  ...        0        0        0
# 500        0        0        0        0  ...        0        0        0
#
#      3/17/20  3/18/20  3/19/20  3/20/20  3/21/20  3/22/20  3/23/20
# ...
